# %%
pip install git+https://github.com/nandometzger/bourbon.git
# Out:
# ...
#   Cloning https://github.com/nandometzger/bourbon.git to /tmp/pip-req-build-tn8n7sn6
#   Running command git clone --filter=blob:none --quiet https://github.com/nandometzger/bourbon.git /tmp/pip-req-build-tn8n7sn6
#   Resolved https://github.com/nandometzger/bourbon.git to commit 4f80a21e638394a14444bd16561483a996a99f7c
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.5/208.5 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 34.0 MB/s eta 0:00:0000:01
# ...
#   Created wheel for bourbon: filename=bourbon-1.2.0-py3-none-any.whl size=25369 sha256=280a53b4f89a063e660add8ca5f54886fce95715063b69e6ac8d4ec6e8d493a5
# ...

# %%
# check if GPU is available
# !nvidia-smi
# Out:
# 'nvidia-smi' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !bourbon-predict \
  --lat -1.9441 --lon 30.0619 \
  --size 512 \
  --provider mpc \
  --ensemble 10 \
  --output kigali_bourbon.png
# Out:
# Loading Model (Bourbon)...
# Error loading model: Torch not compiled with CUDA enabled
# Traceback (most recent call last):
#   File "c:\Users\zollner\AppData\Local\anaconda3\envs\SGR\Lib\site-packages\bourbon\predict_from_coords.py", line 283, in main
#     model = load_model(pretrained=True)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zollner\AppData\Local\anaconda3\envs\SGR\Lib\site-packages\bourbon\__init__.py", line 37, in load_model
#     core_model = POPCORN(**config)
#                  ^^^^^^^^^^^^^^^^^
#   File "c:\Users\zollner\AppData\Local\anaconda3\envs\SGR\Lib\site-packages\bourbon\model\popcorn.py", line 156, in __init__
#     self.building_extractor = self.building_extractor.cuda()
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zollner\AppData\Local\anaconda3\envs\SGR\Lib\site-packages\torch\nn\modules\module.py", line 1093, in cuda
#     return self._apply(lambda t: t.cuda(device))
# ...

# %%
import bourbon
import torch

# Choose device: CUDA if available, MPS (Apple) if available, else CPU
if torch.cuda.is_available():
    device = torch.device("cuda")
elif getattr(torch.backends, "mps", None) and torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

# Load Bourbon model (pretrained)
model = bourbon.load_model(pretrained=True)

# Move model to chosen device
model = model.to(device)

print(f"Bourbon loaded on device: {device}")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[15], line 13
#      10     device = torch.device("cpu")
#      12 # Load Bourbon model (pretrained)
# ---> 13 model = bourbon.load_model(pretrained=True)
#      15 # Move model to chosen device
#      16 model = model.to(device)
#
# File ~/.cache\torch\hub\nandometzger_bourbon_main\bourbon\__init__.py:37, in load_model(pretrained, checkpoint_path, **kwargs)
#      34 config.update(kwargs)
#      36 # Instantiate Core Model
# ---> 37 core_model = POPCORN(**config)
#      39 if pretrained:
#      40     if checkpoint_path is None:
#      41         # Checkpoint from GitHub Releases
#
# ...
